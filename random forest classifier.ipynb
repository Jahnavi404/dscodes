# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv("/home/placement/Downloads/TelecomCustomerChurn.csv")

# %%
data['TotalCharges']=pd.to_numeric(data['TotalCharges'],errors='coerce')

# %%
data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7032.000000
# mean        0.162147    32.371149       64.761692   2283.300441
# std         0.368612    24.559481       30.090047   2266.771362
# min         0.000000     0.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.500000    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.850000   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %%
data.isna().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
data1=data.fillna(data.median())

# %%
data1.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
data.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
list(data1)
# Out:
# ['customerID',
#  'gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'MonthlyCharges',
#  'TotalCharges',
#  'Churn']

# %%
data1.shape
# Out:
# (7043, 21)

# %%
data2=data1.drop(['customerID','customerID','SeniorCitizen','Partner','Dependents','PhoneService','OnlineSecurity','OnlineBackup','DeviceProtection','StreamingTV','StreamingMovies','PaperlessBilling','PaymentMethod',],axis=1)

# %%
data2
# Out:
#       gender  tenure     MultipleLines InternetService TechSupport  \
# 0     Female       1  No phone service             DSL          No
# 1       Male      34                No             DSL          No
# 2       Male       2                No             DSL          No
# 3       Male      45  No phone service             DSL         Yes
# 4     Female       2                No     Fiber optic          No
# ...      ...     ...               ...             ...         ...
# 7038    Male      24               Yes             DSL         Yes
# 7039  Female      72               Yes     Fiber optic          No
# 7040  Female      11  No phone service             DSL          No
# 7041    Male       4               Yes     Fiber optic          No
# 7042    Male      66                No     Fiber optic         Yes
#
#             Contract  MonthlyCharges  TotalCharges Churn
# 0     Month-to-month           29.85         29.85    No
# ...

# %%
data['TotalCharges']=data['TotalCharges'].fillna(data['TotalCharges'].median())

# %%
data.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
data2['Churn']=data2['Churn'].map({'Yes':1,'No':0})

# %%
data2
# Out:
#       gender  tenure     MultipleLines InternetService TechSupport  \
# 0     Female       1  No phone service             DSL          No
# 1       Male      34                No             DSL          No
# 2       Male       2                No             DSL          No
# 3       Male      45  No phone service             DSL         Yes
# 4     Female       2                No     Fiber optic          No
# ...      ...     ...               ...             ...         ...
# 7038    Male      24               Yes             DSL         Yes
# 7039  Female      72               Yes     Fiber optic          No
# 7040  Female      11  No phone service             DSL          No
# 7041    Male       4               Yes     Fiber optic          No
# 7042    Male      66                No     Fiber optic         Yes
#
#             Contract  MonthlyCharges  TotalCharges  Churn
# 0     Month-to-month           29.85         29.85      0
# ...

# %%
databackup=data.copy()

# %%
x=data.drop(['customerID','Churn'],axis=1)
y=data['Churn']

# %%
x=pd.get_dummies(x)

# %%
x
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender_Female  \
# 0                 0       1           29.85         29.85              1
# 1                 0      34           56.95       1889.50              0
# 2                 0       2           53.85        108.15              0
# 3                 0      45           42.30       1840.75              0
# 4                 0       2           70.70        151.65              1
# ...             ...     ...             ...           ...            ...
# 7038              0      24           84.80       1990.50              0
# 7039              0      72          103.20       7362.90              1
# 7040              0      11           29.60        346.45              1
# 7041              1       4           74.40        306.60              0
# 7042              0      66          105.65       6844.50              0
#
#       gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  \
# ...

# %%
data['TotalCharges']=data['TotalCharges'].fillna(data['TotalCharges'].median())

# %%
data.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=42)

# %%
from sklearn.model_selection import GridSearchCV #GridSearchCV is for parameter tuning
from sklearn.ensemble import RandomForestClassifier
cls=RandomForestClassifier()
n_estimators=[25,50,75,100,125,150,175,200] #number of decision trees in the forest, default = 100
criterion=['gini','entropy'] #criteria for choosing nodes default = 'gini'
max_depth=[3,5,10] #maximum number of nodes in a tree default = None (it will go till all possible nodes)
parameters={'n_estimators': n_estimators,'criterion':criterion,'max_depth':max_depth} #this will undergo 8*2*3 = 48 iterations
RFC_cls = GridSearchCV(cls, parameters)
RFC_cls.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 5, 10],
#                          'n_estimators': [25, 50, 75, 100, 125, 150, 175, 200]})

# %%
RFC_cls.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 10, 'n_estimators': 50}

# %%
cls=RandomForestClassifier(n_estimators=100,criterion='entropy',max_depth=10)

# %%
cls.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=10)

# %%
rfy_pred=cls.predict(x_test)
rfy_pred
# Out:
# array(['Yes', 'No', 'No', ..., 'Yes', 'No', 'No'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,rfy_pred)
# Out:
# array([[1549,  148],
#        [ 301,  327]])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,rfy_pred)
# Out:
# 0.8068817204301075
